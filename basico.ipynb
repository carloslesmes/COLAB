# %% [markdown]
# # Python para principantes

# %% [markdown]
# ## Enteros, reales y strings

# %%
type(1)
# Out:
# int

# %%
type(1.5)
# Out:
# float

# %%
type('hola')
# Out:
# str

# %% [markdown]
# ## Variables

# %%
entero = 14

# %%
decimal = 1.845

# %%
nombre = 'Carlos'

# %%
print(entero)
# Out:
# 14

# %%
print(f"hola, mi nombre es {nombre}")
# Out:
# hola, mi nombre es Carlos

# %% [markdown]
# ## Operadores y expresiones

# %%
print("me gusta" + " " + "python")
# Out:
# me gusta python

# %% [markdown]
# ## Aritmética

# %%
10+1
# Out:
# 11

# %%
1.5 - 1
# Out:
# 0.5

# %%
2*3
# Out:
# 6

# %%
4/2.1
# Out:
# 1.9047619047619047

# %%
5//2
# Out:
# 2

# %% [markdown]
# ## Atajos

# %%
x = 1
x += 1
x
# Out:
# 2

# %% [markdown]
# ## Orden de las operaciones

# %%
2+3*5
# Out:
# 17

# %%
(2+3)*5
# Out:
# 25

# %%
2*3**2
# Out:
# 18

# %% [markdown]
# ## Comparaciones

# %%
4>3
# Out:
# True

# %%
4 !=3
# Out:
# True

# %%
x=5
if x<6:
    print("x es menor que 6")
# Out:
# x es menor que 6

# %%
z=6
if x>7:
    print("x es mayor que 7")
else:    print("x no es mayor que 7")
# Out:
# x no es mayor que 7

# %%
veces = 3
while veces > 0:
    print("imprime 3 veces")
    veces -= 1
# Out:
# imprime 3 veces
# imprime 3 veces
# imprime 3 veces

# %% [markdown]
# ## Funciones

# %%
def hola(nombre, apellido):
    print(f"hola, mi nombre es {nombre} {apellido}")

# %%
def suma(x,y):
    return x+y

# %%
suma(2,3)
# Out:
# 5

# %% [markdown]
# ## Estructuras de datos
# Vea [aquí](https://docs.python.org/es/3.14/tutorial/datastructures.html)

# %% [markdown]
# ### Listas

# %%
numeros = [1,2,3,4,5]

# %%
numeros.append(6)
numeros
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numeros.remove(3)
numeros
# Out:
# [1, 2, 4, 5, 6]

# %%
numeros.sort()
numeros
# Out:
# [1, 2, 4, 5, 6]

# %%
palabra="murcielago"

# %%
palabra[0]
# Out:
# 'm'

# %%
palabra[-2]
# Out:
# 'g'

# %%
palabra[2:4]
# Out:
# 'rc'

# %%
palabra[5:]
# Out:
# 'elago'

# %% [markdown]
# ### Tuplas
# Son inmutables

# %%
tupla = (1,2,3,4,5)

# %% [markdown]
# ### Conjuntos

# %%
set([1,2,3,4,5] )
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Diccionarios

# %%
D1={1:"uno", 2:"dos", 3:"tres"}

# %%
D1[2]
# Out:
# 'dos'

# %%
D1[4] = "cuatro"
D1
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres', 4: 'cuatro'}

# %%
# Iterate over keys
for key in D1:
    print(key)
# Out:
# 1
# 2
# 3
# 4

# %%
dicc = dict([("r", 34), ("i", 56)])

# %%
dicc.keys()
# Out:
# dict_keys(['r', 'i'])

# %%
dicc.values()
# Out:
# dict_values([34, 56])
